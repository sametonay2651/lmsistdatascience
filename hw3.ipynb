# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd
dataframe=pd.read_csv("C:/Users/abdulsamet.onay/Desktop/eğitim/bilgeadam python/players.csv")

# %%
dataframe
# Out:
#             _id          birthDate                      birthPlace  \
# 0     abdelal01      June 24, 1968                    Cairo, Egypt
# 1     abdulza01      April 7, 1946              Brooklyn, New York
# 2     abdulka01     April 16, 1947              New York, New York
# 3     abdulma02      March 9, 1969           Gulfport, Mississippi
# 4     abdulta01   November 3, 1974          Maisons Alfort, France
# ...         ...                ...                             ...
# 4680  zizican01    January 4, 1997                  Split, Croatia
# 4681   zoetji01  December 20, 1953                Uxbridge, Canada
# 4682   zopfbi01       June 7, 1948                             NaN
# 4683  zubaciv01     March 18, 1997  Mostar, Bosnia and Herzegovina
# 4684  zunicma01  December 19, 1919            Renton, Pennsylvania
#
#       career_AST career_FG% career_FG3% career_FT%  career_G career_PER  \
# 0            0.3       50.2         0.0       70.1       256       13.0
# ...

# %%
dataframe2=pd.read_csv("C:/Users/abdulsamet.onay/Desktop/eğitim/bilgeadam python/salaries_1985to2018.csv")

# %%
dataframe2.to_excel("salaries_1985to2018.xlsx")

# %%
dataframe.to_excel("players.xlsx")

# %%
import pandas as pd
dataframe3=pd.read_excel("C:/Users/abdulsamet.onay/Desktop/eğitim/bilgeadam python/nihaiveri.xlsx")

# %%
dataframe3
# Out:
#       index         unique         id  salary ($)          birthDate  \
# 0         0  abdelal011990  abdelal01      395000      June 24, 1968
# 1         3  abdulma021990  abdulma02     1660000      March 9, 1969
# 2         4  abdulta011997  abdulta01     1226880   November 3, 1974
# 3         5  abdursh011996  abdursh01     2186000  December 11, 1976
# 4        10  ackeral012005  ackeral01      398762   January 21, 1983
# ...     ...            ...        ...         ...                ...
# 1304   4672  zellety012012  zellety01     1563120   January 17, 1990
# 1305   4676  zidekge011995  zidekge01      603000     August 2, 1973
# 1306   4678  zimmest012016  zimmest01      950000  September 9, 1996
# 1307   4679  zipsepa012016  zipsepa01      750000  February 18, 1994
# 1308   4683  zubaciv012016  zubaciv01     1034956     March 18, 1997
#
#                           birthPlace  career_AST  career_FG%  career_FG3%  \
# ...

# %%
df=dataframe3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        1309 non-null   int64
#  1   unique       1309 non-null   object
#  2   id           1309 non-null   object
#  3   salary ($)   1309 non-null   int64
#  4   birthDate    1309 non-null   object
#  5   birthPlace   1309 non-null   object
#  6   career_AST   1309 non-null   float64
#  7   career_FG%   1309 non-null   float64
#  8   career_FG3%  1309 non-null   float64
#  9   career_FT%   1309 non-null   float64
#  10  career_G     1309 non-null   int64
#  11  career_PER   1309 non-null   float64
#  12  career_PTS   1309 non-null   float64
#  13  career_TRB   1309 non-null   float64
#  14  career_WS    1309 non-null   float64
#  15  career_eFG%  1309 non-null   float64
#  16  college      1181 non-null   object
#  17  draft_pick   1309 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['index', 'unique', 'id', 'salary ($)', 'birthDate', 'birthPlace',
#        'career_AST', 'career_FG%', 'career_FG3%', 'career_FT%', 'career_G',
#        'career_PER', 'career_PTS', 'career_TRB', 'career_WS', 'career_eFG%',
#        'college', 'draft_pick', 'draft_round', 'draft_team', 'draft_year',
#        'height', 'Unnamed: 22', 'height (cm)', 'highSchool', 'name',
#        'position', 'shoots', 'weight (lb)'],
#       dtype='object')

# %%
columns = ['index','unique', 'id','birthDate', 'birthPlace','career_eFG%','college','draft_team','height', 'Unnamed: 22','highSchool', 'name',
       'position']
df.drop(columns, inplace=True, axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   salary ($)   1309 non-null   int64
#  1   career_AST   1309 non-null   float64
#  2   career_FG%   1309 non-null   float64
#  3   career_FG3%  1309 non-null   float64
#  4   career_FT%   1309 non-null   float64
#  5   career_G     1309 non-null   int64
#  6   career_PER   1309 non-null   float64
#  7   career_PTS   1309 non-null   float64
#  8   career_TRB   1309 non-null   float64
#  9   career_WS    1309 non-null   float64
#  10  draft_pick   1309 non-null   int64
#  11  draft_round  1309 non-null   int64
#  12  draft_year   1309 non-null   int64
#  13  height (cm)  1309 non-null   float64
#  14  shoots       1309 non-null   object
#  15  weight (lb)  1309 non-null   int64
# dtypes: float64(9), int64(6), object(1)
# memory usage: 163.8+ KB

# %%
df1=df.dropna()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 1308
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   salary ($)   1309 non-null   int64
#  1   career_AST   1309 non-null   float64
#  2   career_FG%   1309 non-null   float64
#  3   career_FG3%  1309 non-null   float64
#  4   career_FT%   1309 non-null   float64
#  5   career_G     1309 non-null   int64
#  6   career_PER   1309 non-null   float64
#  7   career_PTS   1309 non-null   float64
#  8   career_TRB   1309 non-null   float64
#  9   career_WS    1309 non-null   float64
#  10  draft_pick   1309 non-null   int64
#  11  draft_round  1309 non-null   int64
#  12  draft_year   1309 non-null   int64
#  13  height (cm)  1309 non-null   float64
#  14  shoots       1309 non-null   object
#  15  weight (lb)  1309 non-null   int64
# dtypes: float64(9), int64(6), object(1)
# memory usage: 173.9+ KB

# %%
df1.isnull().sum()
# Out:
# salary ($)     0
# career_AST     0
# career_FG%     0
# career_FG3%    0
# career_FT%     0
# career_G       0
# career_PER     0
# career_PTS     0
# career_TRB     0
# career_WS      0
# draft_pick     0
# draft_round    0
# draft_year     0
# height (cm)    0
# shoots         0
# weight (lb)    0
# dtype: int64

# %%
df1=pd.get_dummies(df1)

# %%
df1
# Out:
#       salary ($)  career_AST  career_FG%  career_FG3%  career_FT%  career_G  \
# 0         395000         0.3        50.2          0.0        70.1       256
# 1        1660000         3.5        44.2         35.4        90.5       586
# 2        1226880         1.1        41.7         23.7        70.3       236
# 3        2186000         2.5        47.2         29.7        81.0       830
# 4         398762         0.5        37.0         32.0        50.0        30
# ...          ...         ...         ...          ...         ...       ...
# 1304     1563120         0.9        50.9         28.6        76.4       412
# 1305      603000         0.2        40.8         25.0        78.3       135
# 1306      950000         0.2        32.3          0.0        60.0        19
# 1307      750000         0.8        37.1         33.5        76.9        98
# 1308     1034956         0.8        54.0          0.0        76.1       140
#
# ...

# %%
df1.corr(method="pearson")
# Out:
#                    salary ($)  career_AST  career_FG%  career_FG3%  \
# salary ($)           1.000000    0.289977    0.168930     0.178809
# career_AST           0.289977    1.000000    0.060092     0.399800
# career_FG%           0.168930    0.060092    1.000000    -0.048053
# career_FG3%          0.178809    0.399800   -0.048053     1.000000
# career_FT%           0.127046    0.365398    0.120864     0.458378
# career_G             0.173629    0.497504    0.327780     0.259877
# career_PER           0.349205    0.469945    0.554672     0.162250
# career_PTS           0.470139    0.658191    0.330924     0.390255
# career_TRB           0.413475    0.188328    0.543175    -0.027857
# career_WS            0.225198    0.530171    0.301705     0.192474
# draft_pick          -0.658048   -0.285629   -0.217109    -0.121426
# draft_round         -0.485396   -0.210904   -0.166470    -0.112749
# draft_year           0.442761   -0.042140   -0.027169     0.123772
# ...

# %%
plt.figure(figsize=[18,12])
sns.heatmap(df1.corr(), cmap="seismic", annot=True, vmin=-1, vmax=1, fmt='.2f');

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn import tree
from sklearn.tree import export_text
import scipy.stats as stats
import statsmodels.api as sm

# %%
Target=df1["salary ($)"]

# %%
column=['salary ($)']
df1.drop(column, inplace=True, axis=1)

# %%
Xtrain, Xtest, Ytrain, Ytest=train_test_split(df1,Target, test_size=0.2, random_state=123)

# %%
#print(Xtrain, Xtest, Ytrain,Ytest)

# %%
Xtrain=sm.add_constant(Xtrain)
# Out:
# C:\Users\abdulsamet.onay\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
mod=sm.OLS(Ytrain,Xtrain)
res=mod.fit()

# %%
print(res)

# %%
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             salary ($)   R-squared:                       0.722
# Model:                            OLS   Adj. R-squared:                  0.718
# Method:                 Least Squares   F-statistic:                     167.2
# Date:                Sun, 20 Nov 2022   Prob (F-statistic):          9.91e-273
# Time:                        19:52:59   Log-Likelihood:                -15323.
# No. Observations:                1047   AIC:                         3.068e+04
# Df Residuals:                    1030   BIC:                         3.076e+04
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const             -7.508e+07   3.26e+06    -23.009      0.000   -8.15e+07   -6.87e+07
# ...

# %% [markdown]
# # ikinci deneme

# %%
df1.columns
# Out:
# Index(['career_AST', 'career_FG%', 'career_FG3%', 'career_FT%', 'career_G',
#        'career_PER', 'career_PTS', 'career_TRB', 'career_WS', 'draft_pick',
#        'draft_round', 'draft_year', 'height (cm)', 'weight (lb)',
#        'shoots_Left', 'shoots_Left Right', 'shoots_Right'],
#       dtype='object')

# %%
df2=df1[['career_AST', 'career_FG%', 'career_FG3%', 'career_FT%', 'career_G', 'career_PTS','height (cm)','draft_pick']]

# %%
Xtrain, Xtest, Ytrain, Ytest=train_test_split(df2,Target, test_size=0.2, random_state=123)

# %%
Xtrain=sm.add_constant(Xtrain)
# Out:
# C:\Users\abdulsamet.onay\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
mod=sm.OLS(Ytrain,Xtrain)
res=mod.fit()

# %%
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             salary ($)   R-squared:                       0.537
# Model:                            OLS   Adj. R-squared:                  0.534
# Method:                 Least Squares   F-statistic:                     150.6
# Date:                Sun, 20 Nov 2022   Prob (F-statistic):          7.48e-168
# Time:                        20:24:37   Log-Likelihood:                -15590.
# No. Observations:                1047   AIC:                         3.120e+04
# Df Residuals:                    1038   BIC:                         3.124e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -1.996e+06   7.64e+05     -2.611      0.009    -3.5e+06   -4.96e+05
# ...

# %% [markdown]
# # 3.deneme

# %%
df3=df1[[ 'career_FG3%', 'career_FT%', 'career_PTS','height (cm)','draft_pick']]

# %%
Xtrain, Xtest, Ytrain, Ytest=train_test_split(df3,Target, test_size=0.2, random_state=123)

# %%
Xtrain=sm.add_constant(Xtrain)
# Out:
# C:\Users\abdulsamet.onay\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
mod=sm.OLS(Ytrain,Xtrain)
res=mod.fit()

# %%
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             salary ($)   R-squared:                       0.468
# Model:                            OLS   Adj. R-squared:                  0.465
# Method:                 Least Squares   F-statistic:                     182.9
# Date:                Sun, 20 Nov 2022   Prob (F-statistic):          8.79e-140
# Time:                        20:26:27   Log-Likelihood:                -15663.
# No. Observations:                1047   AIC:                         3.134e+04
# Df Residuals:                    1041   BIC:                         3.137e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const         2.54e+05   6.57e+05      0.387      0.699   -1.04e+06    1.54e+06
# ...

# %% [markdown]
# # 4.deneme

# %%
df4=df1[['career_AST', 'career_FG%', 'career_FG3%', 'career_FT%', 'career_PTS', 'draft_pick', 'draft_year', 'height (cm)']]

# %%
Xtrain, Xtest, Ytrain, Ytest=train_test_split(df4,Target, test_size=0.2, random_state=123)

# %%
Xtrain=sm.add_constant(Xtrain)
# Out:
# C:\Users\abdulsamet.onay\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
mod=sm.OLS(Ytrain,Xtrain)
res=mod.fit()

# %%
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             salary ($)   R-squared:                       0.665
# Model:                            OLS   Adj. R-squared:                  0.663
# Method:                 Least Squares   F-statistic:                     257.7
# Date:                Sun, 20 Nov 2022   Prob (F-statistic):          1.87e-240
# Time:                        20:28:59   Log-Likelihood:                -15421.
# No. Observations:                1047   AIC:                         3.086e+04
# Df Residuals:                    1038   BIC:                         3.090e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -1.031e+08   4.21e+06    -24.474      0.000   -1.11e+08   -9.48e+07
# ...

# %% [markdown]
# # deneme5

# %%
df5=df1[['career_AST',  'career_FG3%', 'career_FT%', 'career_PTS', 'draft_pick', 'draft_year', 'height (cm)']]

# %%
Xtrain, Xtest, Ytrain, Ytest=train_test_split(df5,Target, test_size=0.2, random_state=123)

# %%
Xtrain=sm.add_constant(Xtrain)
# Out:
# C:\Users\abdulsamet.onay\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
mod=sm.OLS(Ytrain,Xtrain)
res=mod.fit()

# %%
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             salary ($)   R-squared:                       0.665
# Model:                            OLS   Adj. R-squared:                  0.663
# Method:                 Least Squares   F-statistic:                     294.6
# Date:                Sun, 20 Nov 2022   Prob (F-statistic):          1.32e-241
# Time:                        20:30:29   Log-Likelihood:                -15421.
# No. Observations:                1047   AIC:                         3.086e+04
# Df Residuals:                    1039   BIC:                         3.090e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -1.031e+08   4.21e+06    -24.484      0.000   -1.11e+08   -9.48e+07
# ...

# %% [markdown]
# # 6.deneme

# %%
Ytrain
# Out:
# 1155     987000
# 964     1474000
# 1127     901880
# 406      700000
# 919     1527946
#          ...
# 1238      75000
# 1147     150000
# 106     2798040
# 1041     242250
# 1122     423762
# Name: salary ($), Length: 1047, dtype: int64

# %%
log_reg=sm.Logit(df["salary ($)"],Xtrain).fit()
log_reg=sm.Logit
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\ABDULS~1.ONA\AppData\Local\Temp/ipykernel_9324/1023590526.py in <module>
# ----> 1 log_reg=sm.Logit(df["salary ($)"],Xtrain).fit()
#       2 log_reg=sm.Logit
#
# ~\Anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py in __init__(self, endog, exog, check_rank, **kwargs)
#     455
#     456     def __init__(self, endog, exog, check_rank=True, **kwargs):
# --> 457         super().__init__(endog, exog, check_rank, **kwargs)
#     458
#     459         if not issubclass(self.__class__, MultinomialModel):
#
# ~\Anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py in __init__(self, endog, exog, check_rank, **kwargs)
#     173     def __init__(self, endog, exog, check_rank=True, **kwargs):
#     174         self._check_rank = check_rank
# --> 175         super().__init__(endog, exog, **kwargs)
# ...

# %%
pri

# %%
y_train=df1['salary ($)']

# %%
column=['salary ($)']
df1.drop(column, inplace=True, axis=1)

# %%
y_train
# Out:
# 0        395000
# 1       1660000
# 2       1226880
# 3       2186000
# 4        398762
#          ...
# 1304    1563120
# 1305     603000
# 1306     950000
# 1307     750000
# 1308    1034956
# Name: salary ($), Length: 1309, dtype: int64

# %%
df1
# Out:
#       career_AST  career_FG%  career_FG3%  career_FT%  career_G  career_PER  \
# 0            0.3        50.2          0.0        70.1       256        13.0
# 1            3.5        44.2         35.4        90.5       586        15.4
# 2            1.1        41.7         23.7        70.3       236        11.4
# 3            2.5        47.2         29.7        81.0       830        19.0
# 4            0.5        37.0         32.0        50.0        30         8.5
# ...          ...         ...          ...         ...       ...         ...
# 1304         0.9        50.9         28.6        76.4       412        14.9
# 1305         0.2        40.8         25.0        78.3       135         8.7
# 1306         0.2        32.3          0.0        60.0        19         7.3
# 1307         0.8        37.1         33.5        76.9        98         6.1
# 1308         0.8        54.0          0.0        76.1       140        17.6
#
# ...

# %%
atamay=y_train
atamax=df1
